# %%
## Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
## Reading the given data
pd.set_option('display.max_columns', None)
data = pd.read_csv(r"C:\Users\sumit\OneDrive\Desktop\Projects\Particle_Physics_Classification\Data_new.csv")
data.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3                  9.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
data.shape
# Out:
# (250000, 33)

# %%
data.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     -49.023079                    49.239819
# std     72168.927986     406.345647                    35.344886
# min    100000.000000    -999.000000                     0.000000
# 25%    162499.750000      78.100750                    19.241000
# 50%    224999.500000     105.012000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000         250000.000000     250000.000000
# mean       81.181982      57.895962           -708.416643       -601.237051
# std        40.828691      63.655682            454.482458        657.972302
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   EventId                      250000 non-null  int64
#  1   DER_mass_MMC                 250000 non-null  float64
#  2   DER_mass_transverse_met_lep  250000 non-null  float64
#  3   DER_mass_vis                 250000 non-null  float64
#  4   DER_pt_h                     250000 non-null  float64
#  5   DER_deltaeta_jet_jet         250000 non-null  float64
#  6   DER_mass_jet_jet             250000 non-null  float64
#  7   DER_prodeta_jet_jet          250000 non-null  float64
#  8   DER_deltar_tau_lep           250000 non-null  float64
#  9   DER_pt_tot                   250000 non-null  float64
#  10  DER_sum_pt                   250000 non-null  float64
#  11  DER_pt_ratio_lep_tau         250000 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# EventId                        0
# DER_mass_MMC                   0
# DER_mass_transverse_met_lep    0
# DER_mass_vis                   0
# DER_pt_h                       0
# DER_deltaeta_jet_jet           0
# DER_mass_jet_jet               0
# DER_prodeta_jet_jet            0
# DER_deltar_tau_lep             0
# DER_pt_tot                     0
# DER_sum_pt                     0
# DER_pt_ratio_lep_tau           0
# DER_met_phi_centrality         0
# DER_lep_eta_centrality         0
# PRI_tau_pt                     0
# PRI_tau_eta                    0
# PRI_tau_phi                    0
# PRI_lep_pt                     0
# PRI_lep_eta                    0
# PRI_lep_phi                    0
# PRI_met                        0
# PRI_met_phi                    0
# PRI_met_sumet                  0
# PRI_jet_num                    0
# PRI_jet_leading_pt             0
# PRI_jet_leading_eta            0
# PRI_jet_leading_phi            0
# PRI_jet_subleading_pt          0
# ...

# %%
data.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt',
#        'Weight', 'Label'],
#       dtype='object')

# %% [markdown]
# # EDA
# ### Univariate Analysis

# %%
data.tail(5)
# Out:
#         EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 249995   349995      -999.000                       71.989        36.548
# 249996   349996      -999.000                       58.179        68.083
# 249997   349997       105.457                       60.526        75.839
# 249998   349998        94.951                       19.362        68.812
# 249999   349999      -999.000                       72.756        70.831
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 249995     5.042                -999.0            -999.0               -999.0
# 249996    22.439                -999.0            -999.0               -999.0
# 249997    39.757                -999.0            -999.0               -999.0
# 249998    13.504                -999.0            -999.0               -999.0
# 249999     7.479                -999.0            -999.0               -999.0
#
# ...

# %%
data.head(5)
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3                  9.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
## We can see from here that the minimum number of jets formed in the collision experiment is 3.

print(data["Label"].value_counts())
print()
print(data["PRI_jet_num"].value_counts())
# Out:
# Label
# b    164333
# s     85667
# Name: count, dtype: int64
#
# PRI_jet_num
# 0    99913
# 1    77544
# 2    50379
# 3    22164
# Name: count, dtype: int64

# %%
50379/250000
# Out:
# 0.201516

# %% [markdown]
# ### Calculating Unique values in each Feature

# %%
unique_value = []

for i in data.columns:
    unique_value.append((i,data[i].nunique()))
unique_value = sorted(unique_value,reverse = True)

for i,j in unique_value:
    print(f"{i} :    {j} :    {round(j/168457*100,3)}%")
# Out:
# Weight :    104094 :    61.793%
# PRI_tau_pt :    59639 :    35.403%
# PRI_tau_phi :    6285 :    3.731%
# PRI_tau_eta :    4971 :    2.951%
# PRI_met_sumet :    179740 :    106.698%
# PRI_met_phi :    6285 :    3.731%
# PRI_met :    87836 :    52.141%
# PRI_lep_pt :    61929 :    36.762%
# PRI_lep_phi :    6285 :    3.731%
# PRI_lep_eta :    4987 :    2.96%
# PRI_jet_subleading_pt :    42464 :    25.208%
# PRI_jet_subleading_phi :    6286 :    3.732%
# PRI_jet_subleading_eta :    8628 :    5.122%
# PRI_jet_num :    4 :    0.002%
# PRI_jet_leading_pt :    86590 :    51.402%
# PRI_jet_leading_phi :    6285 :    3.731%
# PRI_jet_leading_eta :    8558 :    5.08%
# PRI_jet_all_pt :    103559 :    61.475%
# Label :    2 :    0.001%
# EventId :    250000 :    148.406%
# DER_sum_pt :    156098 :    92.663%
# DER_pt_tot :    59042 :    35.049%
# DER_pt_ratio_lep_tau :    5931 :    3.521%
# DER_pt_h :    115563 :    68.601%
# DER_prodeta_jet_jet :    16593 :    9.85%
# ...

# %%
## Count of Independent Variable 

sns.set_theme(style="white",context="talk",font="cursive")
plt.figure(figsize=(23,10))
plt.xlabel('Label')
plt.ylabel('Count')
plt.title('Count of Labels')
grid = sns.countplot(x='Label', data=data)
grid.bar_label(grid.containers[0])
plt.show()

# %%
## Count of No of Jets formed 

sns.set_theme(style="darkgrid",context="poster",font="cursive")
plt.figure(figsize=(20,10))
plt.xlabel('No of Jets')
plt.ylabel('Count')
plt.title('Number of Jets formed')
grid = sns.countplot(x='PRI_jet_num', data=data)
grid.bar_label(grid.containers[0])
plt.show()

# %%
## Count of transverse momentum of Tau particles
sns.set_theme(style="white",context="talk",font="cursive",palette="Set1")
plt.figure(figsize=(20,10),dpi=50)
plt.hist(x="PRI_tau_pt",bins =100,data=data)
plt.xlabel('No of Bins',labelpad=10)
plt.ylabel('Count of Transverse Momentum of Tau Particle',labelpad=10)
plt.title("PRI_tau_pt in term of Bins",y=1.04)
plt.xlim(0, 400)
plt.ylim(0,100000)
plt.show()

# %%
## Probability density function of Weight column 
sns.set_theme(style="whitegrid",context="talk",font="cursive",palette="Set1")
plt.figure(figsize=(20,10),dpi=50)
sns.kdeplot(x="Weight",color='b', shade=True,data=data)
plt.xlabel('Weight value',labelpad=10)
plt.ylabel('Density',labelpad=15)
plt.title("KDE plot of Weight",y=1.04)
plt.show()
## Most data points of weight lies in range of 0 to 1

# %%
## Derived Mass by conservation of momemtum
sns.set_theme(style="darkgrid",context="talk",font="cursive",palette="Set1")
plt.figure(figsize=(20,10),dpi=50)
sns.stripplot(x = "DER_mass_MMC", data=data)
plt.xlabel('Mass value',labelpad=10)
plt.title("Striplot of Missing mass calculator",y=1.05)
plt.show()
##  Most Data points lies from 0 to 500 while some points are - 999

# %%
## Among the 3 below columns they don't have any negative mass value
order = data.value_counts().index
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.violinplot(x = "DER_mass_transverse_met_lep", data=data, order=order,color="k")
plt.subplot(1,3,2)
sns.violinplot(x = "DER_mass_vis", data=data, order=order,color="y")
plt.subplot(1,3,3)
sns.stripplot(x = "DER_pt_h", data=data)
plt.show()

# %%
## Total 11 columns have -999 value while some are mass values and others related to angles.
def has_minus_999(column):
    return column.eq(-999).any() 

cols_with_minus_999 = [i for i in data.columns if has_minus_999(data[i])]
for i in cols_with_minus_999:
    print(i)
print()
print("Total Columns with -999 value :-",len(cols_with_minus_999))
# Out:
# DER_mass_MMC
# DER_deltaeta_jet_jet
# DER_mass_jet_jet
# DER_prodeta_jet_jet
# DER_lep_eta_centrality
# PRI_jet_leading_pt
# PRI_jet_leading_eta
# PRI_jet_leading_phi
# PRI_jet_subleading_pt
# PRI_jet_subleading_eta
# PRI_jet_subleading_phi
#
# Total Columns with -999 value :- 11

# %%
## Among the 3 below columns we can see most data points lie around -999
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.kdeplot(x = "DER_deltaeta_jet_jet",color='b', shade=True,data=data)
plt.subplot(1,3,2)
sns.kdeplot(x="DER_mass_jet_jet",color='y', shade=True,data=data)
plt.subplot(1,3,3)
sns.kdeplot(x="DER_prodeta_jet_jet",color='c', shade=True,data=data)
plt.show()

# %%
## Among the 3 below columns we can see many data points lie around -999
sns.set_theme(style="white",context="talk",font="cursive",palette="bright")
plt.figure(figsize=(25,8),dpi=50)
plt.subplot(1,3,1)
sns.stripplot(x="DER_lep_eta_centrality",color='b',data=data)
plt.subplot(1,3,2)
sns.stripplot(x="PRI_jet_leading_pt",color='r',data=data)
plt.subplot(1,3,3)
sns.stripplot(x="PRI_jet_leading_eta",color='g',data=data)
plt.show()

# %%
## Among the 3 below columns we can see many data points lie around -999 as well as near 0 point
sns.set_theme(style="darkgrid",context="talk",font="sans",palette="bright")
plt.figure(figsize=(25,8),dpi=50)
plt.subplot(1,3,1)
sns.violinplot(x="PRI_jet_leading_phi",color='y',data=data)
plt.subplot(1,3,2)
sns.violinplot(x="PRI_jet_subleading_pt",color='w',data=data)
plt.subplot(1,3,3)
sns.violinplot(x="PRI_jet_subleading_eta",color='m',data=data)
plt.show()

# %%
## Among the 3 below columns we can see data points distributed across different data points and some outliers presence
sns.set_theme(style="darkgrid",context="talk",font="sans",palette="bright")
plt.figure(figsize=(25,8),dpi=50)
plt.subplot(1,3,1)
sns.scatterplot(data["DER_deltar_tau_lep"],color='k')
plt.subplot(1,3,2)
sns.scatterplot(data["DER_pt_tot"],color='b')
plt.subplot(1,3,3)
sns.scatterplot(data["DER_sum_pt"],color='g')
plt.show()

# %%
## As we can see in this column major data points lies from 0 to 5
sns.jointplot(data["DER_pt_ratio_lep_tau"],color='r')
plt.show()

# %%
## As we can see in this column major data points lies near -1.4 and +1.4
sns.jointplot(data["DER_met_phi_centrality"],color='y')
plt.show()

# %%
## Among the 3 below columns we can see the distribution of data points.
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
plt.figure(figsize=(30,8),dpi=50)
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.kdeplot(data["PRI_tau_pt"],color='g', shade=True)
plt.subplot(1,3,2)
sns.kdeplot(data["PRI_tau_eta"],color='m', shade=True)
plt.subplot(1,3,3)
sns.kdeplot(data["PRI_tau_phi"],color='r', shade=True)
plt.show()

# %%
## We can see that transverse momentum is majorly on lower side and lepton angles is distributed among all points
sns.set_theme(style="white",context="talk",font="cursive",palette="bright")
plt.figure(figsize=(25,8),dpi=50)
plt.subplot(1,3,1)
sns.stripplot(data["PRI_lep_pt"],color='b')
plt.subplot(1,3,2)
sns.stripplot(data["PRI_lep_eta"],color='r')
plt.subplot(1,3,3)
sns.stripplot(data["PRI_lep_phi"],color='g')
plt.show()

# %%
## Among the 3 below columns we can see data points distributed across different data points and some outliers presence
sns.set_theme(style="darkgrid",context="talk",font="sans",palette="bright")
plt.figure(figsize=(25,8),dpi=50)
plt.subplot(1,3,1)
sns.scatterplot(data["PRI_met"],color='y')
plt.subplot(1,3,2)
sns.scatterplot(data["PRI_met_phi"],color='b')
plt.subplot(1,3,3)
sns.scatterplot(data["PRI_met_sumet"],color='g')
plt.show()

# %%
## Converting Target variable to machine learning language
data['Label'] = data['Label'].replace({'s':1, "b":0})

# %%
## Checking which columns have more than 90% correlation
data.corr()
# Out:
#                               EventId  DER_mass_MMC  \
# EventId                      1.000000      0.001917
# DER_mass_MMC                 0.001917      1.000000
# DER_mass_transverse_met_lep -0.006059     -0.455755
# DER_mass_vis                -0.001851      0.168548
# DER_pt_h                     0.002073      0.198765
# DER_deltaeta_jet_jet        -0.000075      0.162664
# DER_mass_jet_jet             0.000353      0.160524
# DER_prodeta_jet_jet         -0.000075      0.162521
# DER_deltar_tau_lep          -0.001349      0.228105
# DER_pt_tot                  -0.000581      0.045826
# DER_sum_pt                   0.001427      0.201464
# DER_pt_ratio_lep_tau        -0.001209     -0.017073
# DER_met_phi_centrality       0.003393      0.358963
# DER_lep_eta_centrality      -0.000063      0.162623
# PRI_tau_pt                   0.002829      0.131495
# PRI_tau_eta                  0.001573      0.002579
# PRI_tau_phi                 -0.000467     -0.006177
# ...

# %%
data.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt',
#        'Weight', 'Label'],
#       dtype='object')

# %%
## Dropping highly correlated columns with correlation of more than 0.9
data.drop(["EventId","DER_deltaeta_jet_jet","DER_prodeta_jet_jet","DER_lep_eta_centrality","PRI_met_sumet","PRI_jet_leading_eta","PRI_jet_leading_phi",
        "PRI_jet_subleading_pt","PRI_jet_subleading_eta","PRI_jet_subleading_phi","PRI_jet_all_pt","DER_met_phi_centrality"],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_pt_h', 'DER_mass_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot',
#        'DER_sum_pt', 'DER_pt_ratio_lep_tau', 'PRI_tau_pt', 'PRI_tau_eta',
#        'PRI_tau_phi', 'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met',
#        'PRI_met_phi', 'PRI_jet_num', 'PRI_jet_leading_pt', 'Weight', 'Label'],
#       dtype='object')

# %% [markdown]
# ### Bivariate Analysis

# %%
## To ingore warnings of matplotlib
plt.set_loglevel('WARNING')

# %%
## Plot between No of jets formed vs other features
a = 'PRI_jet_num'
order = data[a].value_counts().index
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sns.boxplot(x=data[a],y=data["DER_mass_MMC"],order=order)
plt.subplot(1,3,2)
sns.violinplot(x=data[a],y=data["DER_mass_transverse_met_lep"],order=order)
plt.subplot(1,3,3)
sns.stripplot(x=data[a],y=data["DER_mass_vis"],order=order)
plt.show()

# %%
## Plot between Labels formed vs other features
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
a = 'Label'
order = data[a].value_counts().index
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sns.boxplot(x=data[a],y=data["DER_mass_MMC"],order=order,color="r")
plt.subplot(1,3,2)
sns.violinplot(x=data[a],y=data["DER_mass_transverse_met_lep"],order=order,color="y")
plt.subplot(1,3,3)
sns.stripplot(x=data[a],y=data["DER_mass_vis"],order=order,color="g")
plt.show()

# %%
## Plot between Labels formed vs other features
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
a = 'Label'
order = data[a].value_counts().index
plt.figure(figsize=(25,6))
plt.subplot(1,3,1)
sns.boxplot(x=data[a],y=data["DER_pt_h"],order=order,color="m")
plt.subplot(1,3,2)
sns.violinplot(x=data[a],y=data["DER_mass_jet_jet"],order=order,color="r")
plt.subplot(1,3,3)
sns.stripplot(x=data[a],y=data["DER_deltar_tau_lep"],color="b")
plt.show()

# %%
## Plot between No of jets formed vs other features
sns.set_theme(style="dark",context="talk",font="sans",palette="bright")
a = 'PRI_jet_num'
order = data[a].value_counts().index
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sns.boxplot(x=data[a],y=data["PRI_met_phi"],order=order)
plt.subplot(1,3,2)
sns.violinplot(x=data[a],y=data["DER_sum_pt"],order=order)
plt.subplot(1,3,3)
sns.stripplot(x=data[a],y=data["DER_pt_ratio_lep_tau"],order=order,color="m")
plt.show()

# %%
## Plot between No of jets formed and Labels vs Weight
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
a = 'PRI_jet_num'
b= "Label"
order1 = data[a].value_counts().index
order2 = data[b].value_counts().index
plt.figure(figsize=(22,6))
plt.subplot(1,2,1)
sns.stripplot(x=data[a],y=data["Weight"],order=order1,color = "y")
plt.subplot(1,2,2)
sns.stripplot(x=data[b],y=data["Weight"],order=order2,color="r")
plt.show()

# %%
## Value counts of Label "s" w.r.t Weight
data[data.Label==1].groupby(["Label"]).Weight.value_counts().sum()
# Out:
# 85667

# %%
## Value counts of Label "b" w.r.t Weight
data[data.Label==0].groupby(["Label"]).Weight.value_counts().sum()
# Out:
# 164333

# %%
## Value counts of jets formed w.r.t Weight
print(data[data.PRI_jet_num==0].groupby(["PRI_jet_num"]).Weight.value_counts().sum())
print()
print(data[data.PRI_jet_num==1].groupby(["PRI_jet_num"]).Weight.value_counts().sum())
print()
print(data[data.PRI_jet_num==2].groupby(["PRI_jet_num"]).Weight.value_counts().sum())
print()
print(data[data.PRI_jet_num==3].groupby(["PRI_jet_num"]).Weight.value_counts().sum())
# Out:
# 99913
#
# 77544
#
# 50379
#
# 22164

# %%
## Plot between Independent variable and Mass of particles and jets
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
b= "Label"
plt.figure(figsize=(22,6))
plt.subplot(1,2,1)
sns.stripplot(x=data[b],y=data["DER_mass_jet_jet"],color = "b")
plt.subplot(1,2,2)
sns.stripplot(x=data[b],y=data["DER_mass_MMC"],color="g")
plt.show()

# %%
## Plot between Independent variable and Mass of visible particles and higgs boson and missing energy
sns.set_theme(style="darkgrid",context="talk",font="sans",palette="bright")
b= "Label"
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sns.scatterplot(x=data[b],y=data["DER_mass_transverse_met_lep"],color = "y")
plt.subplot(1,3,2)
sns.scatterplot(x=data[b],y=data["DER_mass_vis"],color="m")
plt.subplot(1,3,3)
sns.scatterplot(x=data[b],y=data["DER_pt_h"],color="r")
plt.show()

# %%
## Plot between Independent variable and abs pseudorapidity tau lepton and total momentum and total momentum
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
b= "Label"
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sns.stripplot(x=data[b],y=data["DER_deltar_tau_lep"],color = "b")
plt.subplot(1,3,2)
sns.stripplot(x=data[b],y=data["DER_pt_tot"],color="g")
plt.subplot(1,3,3)
sns.stripplot(x=data[b],y=data["DER_sum_pt"],color="k")
plt.show()

# %%
## Plot between Independent variable and lepton particle, azimuthal angle and missing energy
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
b= "Label"
plt.figure(figsize=(22,6))
plt.subplot(1,3,1)
sns.stripplot(x=data[b],y=data["PRI_lep_pt"],color = "c")
plt.subplot(1,3,2)
sns.stripplot(x=data[b],y=data["PRI_lep_phi"],color="m")
plt.subplot(1,3,3)
sns.stripplot(x=data[b],y=data["PRI_met"],color="y")
plt.show()

# %%
## Plot between Independent variable and jets , missing transverse azimuthal angle and leading jet transverse momentum
sns.set_theme(style="white",context="talk",font="sans",palette="bright")
b= "Label"
plt.figure(figsize=(24,6))
plt.subplot(1,3,1)
sns.stripplot(x=data[b],y=data["PRI_jet_num"],color = "r")
plt.subplot(1,3,2)
sns.stripplot(x=data[b],y=data["PRI_met_phi"],color="g")
plt.subplot(1,3,3)
sns.stripplot(x=data[b],y=data["PRI_jet_leading_pt"],color="k")
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
## Boxplot for checking ouliers
plt.figure(figsize=(9,7))
data.boxplot(vert=0)
plt.title("Outlier")
plt.show()

# %%
## Converting Mass mmc and mass jet jet where value is -999 to zero

data1 = data.copy()
data1["DER_mass_MMC"]=data1["DER_mass_MMC"].replace([-999],0)
data1["DER_mass_jet_jet"]=data1["DER_mass_jet_jet"].replace([-999],0)
data1["PRI_jet_leading_pt"]=data1["PRI_jet_leading_pt"].replace([-999],0)

# %%
data1.DER_mass_jet_jet.value_counts()
# Out:
# DER_mass_jet_jet
# 0.000      177457
# 161.729         5
# 104.928         4
# 83.358          4
# 91.095          4
#             ...
# 755.222         1
# 319.750         1
# 637.681         1
# 382.036         1
# 119.437         1
# Name: count, Length: 68366, dtype: int64

# %%
data1.PRI_jet_leading_pt.value_counts()
# Out:
# PRI_jet_leading_pt
# 0.000      99913
# 36.358        10
# 30.363        10
# 31.739        10
# 36.493        10
#            ...
# 62.489         1
# 72.548         1
# 53.942         1
# 129.874        1
# 141.752        1
# Name: count, Length: 86590, dtype: int64

# %%
data1.DER_mass_MMC.value_counts()
# Out:
# DER_mass_MMC
# 0.000      38114
# 108.914       10
# 96.819        10
# 103.762       10
# 108.957       10
#            ...
# 47.910         1
# 274.769        1
# 191.831        1
# 200.830        1
# 217.020        1
# Name: count, Length: 108338, dtype: int64

# %%
data1.drop(["PRI_jet_leading_pt","DER_mass_jet_jet"],axis=1,inplace=True)

# %%
data1.describe()
# Out:
#         DER_mass_MMC  DER_mass_transverse_met_lep   DER_mass_vis  \
# count  250000.000000                250000.000000  250000.000000
# mean      103.280465                    49.239819      81.181982
# std        68.566103                    35.344886      40.828691
# min         0.000000                     0.000000       6.329000
# 25%        78.100750                    19.241000      59.388750
# 50%       105.012000                    46.524000      73.752000
# 75%       130.606250                    73.598000      92.259000
# max      1192.026000                   690.075000    1349.351000
#
#             DER_pt_h  DER_deltar_tau_lep     DER_pt_tot     DER_sum_pt  \
# count  250000.000000       250000.000000  250000.000000  250000.000000
# mean       57.895962            2.373100      18.917332     158.432217
# std        63.655682            0.782911      22.273494     115.706115
# min         0.000000            0.208000       0.000000      46.104000
# ...

# %%
data1["DER_mass_MMC"]=data1.DER_mass_MMC.replace([0],105.012000)
data1
# Out:
#         DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0            138.470                       51.655        97.827    27.980
# 1            160.937                       68.768       103.235    48.146
# 2            105.012                      162.172       125.953    35.635
# 3            143.905                       81.417        80.943     0.414
# 4            175.864                       16.915       134.805    16.405
# ...              ...                          ...           ...       ...
# 249995       105.012                       71.989        36.548     5.042
# 249996       105.012                       58.179        68.083    22.439
# 249997       105.457                       60.526        75.839    39.757
# 249998        94.951                       19.362        68.812    13.504
# 249999       105.012                       72.756        70.831     7.479
#
#         DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
plt.figure(figsize=(9,7))
data1.boxplot(vert=0)
plt.title("Outlier")
plt.show()

# %%
# Number of outliers

def outlier_check(data, n):
    for col in data.columns:
        if data[col].dtype == 'int64' or data[col].dtype=='float64' :
            Q1 = data[col].quantile(0.25)
            Q3 = data[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_range = Q1 - (n * IQR)
            upper_range = Q3 + (n * IQR)
            print("Number of outliers in ",col,":-", data[(data[col] > upper_range) | (data[col] < lower_range)].shape[0])

# %%
outlier_check(data1,1.5)
# Out:
# Number of outliers in  DER_mass_MMC :- 19989
# Number of outliers in  DER_mass_transverse_met_lep :- 1850
# Number of outliers in  DER_mass_vis :- 14611
# Number of outliers in  DER_pt_h :- 13891
# Number of outliers in  DER_deltar_tau_lep :- 644
# Number of outliers in  DER_pt_tot :- 8632
# Number of outliers in  DER_sum_pt :- 12289
# Number of outliers in  DER_pt_ratio_lep_tau :- 9566
# Number of outliers in  PRI_tau_pt :- 13925
# Number of outliers in  PRI_tau_eta :- 0
# Number of outliers in  PRI_tau_phi :- 0
# Number of outliers in  PRI_lep_pt :- 13434
# Number of outliers in  PRI_lep_eta :- 0
# Number of outliers in  PRI_lep_phi :- 0
# Number of outliers in  PRI_met :- 13299
# Number of outliers in  PRI_met_phi :- 0
# Number of outliers in  PRI_jet_num :- 0
# Number of outliers in  Weight :- 5452
# Number of outliers in  Label :- 0

# %%
def outlier_treatment(x):
    q5 = np.percentile(x,5)
    q25 = np.percentile(x,25)
    q75 = np.percentile(x,75)
    q95= np.percentile(x,95)
 
    IQR = q75 - q25

    lower_bound = q25 - 1.5 * IQR
    upper_bound = q75 + 1.5 * IQR
    print(q5, q25, q75, q95, min, max)
   
    return x.apply(lambda y: q75 if y > upper_bound else y).apply(lambda y :25 if y < lower_bound else y )

# %%
for i in data1:
    data1[i] = outlier_treatment(data1[i])
# Out:
# 67.37985 95.665 130.60625 201.808 <built-in function min> <built-in function max>
# 3.3889500000000004 19.241 73.598 104.64419999999996 <built-in function min> <built-in function max>
# 37.87395 59.38875 92.259 149.27005 <built-in function min> <built-in function max>
# 1.201 14.068750000000001 79.169 183.4911 <built-in function min> <built-in function max>
# 0.973 1.81 2.961 3.441 <built-in function min> <built-in function max>
# 0.733 2.841 27.591 56.68914999999996 <built-in function min> <built-in function max>
# 55.973 77.55 200.47825 383.0023999999999 <built-in function min> <built-in function max>
# 0.488 0.883 1.777 2.897 <built-in function min> <built-in function max>
# 20.787 24.591749999999998 45.017 77.8824499999999 <built-in function min> <built-in function max>
# -2.011 -0.925 0.898 2.011 <built-in function min> <built-in function max>
# -2.829 -1.575 1.565 2.83 <built-in function min> <built-in function max>
# ...

# %%
outlier_check(data1,1.5)
# Out:
# Number of outliers in  DER_mass_MMC :- 3440
# Number of outliers in  DER_mass_transverse_met_lep :- 0
# Number of outliers in  DER_mass_vis :- 0
# Number of outliers in  DER_pt_h :- 0
# Number of outliers in  DER_deltar_tau_lep :- 0
# Number of outliers in  DER_pt_tot :- 0
# Number of outliers in  DER_sum_pt :- 0
# Number of outliers in  DER_pt_ratio_lep_tau :- 0
# Number of outliers in  PRI_tau_pt :- 0
# Number of outliers in  PRI_tau_eta :- 0
# Number of outliers in  PRI_tau_phi :- 0
# Number of outliers in  PRI_lep_pt :- 0
# Number of outliers in  PRI_lep_eta :- 0
# Number of outliers in  PRI_lep_phi :- 0
# Number of outliers in  PRI_met :- 0
# Number of outliers in  PRI_met_phi :- 0
# Number of outliers in  PRI_jet_num :- 0
# Number of outliers in  Weight :- 0
# Number of outliers in  Label :- 0

# %%
plt.figure(figsize=(9,7))
data1.boxplot(vert=0)
plt.title("Outlier")
plt.show()

# %%
data1_new = data1.copy()
data1_new
# Out:
#         DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0            138.470                       51.655        97.827    27.980
# 1            160.937                       68.768       103.235    48.146
# 2            105.012                       73.598       125.953    35.635
# 3            143.905                       81.417        80.943     0.414
# 4            175.864                       16.915       134.805    16.405
# ...              ...                          ...           ...       ...
# 249995       105.012                       71.989        36.548     5.042
# 249996       105.012                       58.179        68.083    22.439
# 249997       105.457                       60.526        75.839    39.757
# 249998        94.951                       19.362        68.812    13.504
# 249999       105.012                       72.756        70.831     7.479
#
#         DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler_columns = ['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',"DER_pt_h","DER_deltar_tau_lep",
                 "DER_pt_tot","DER_sum_pt","DER_pt_ratio_lep_tau","PRI_tau_pt","PRI_tau_eta",
                 "PRI_tau_phi","PRI_lep_pt","PRI_lep_eta","PRI_lep_phi","PRI_met","PRI_met_phi","PRI_jet_num","Weight"]
data1_new[scaler_columns] = scaler.fit_transform(data1_new[scaler_columns])

# %%
data1_new
# Out:
#         DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0           1.061896                     0.104625      1.002061 -0.495668
# 1           1.906809                     0.633435      1.238148 -0.012273
# 2          -0.196353                     0.782687      2.229903 -0.312172
# 3           1.266289                     1.024303      0.264989 -1.156447
# 4           2.468166                    -0.968879      2.616337 -0.773130
# ...              ...                          ...           ...       ...
# 249995     -0.196353                     0.732968     -1.673076 -1.045510
# 249996     -0.196353                     0.306224     -0.296414 -0.628491
# 249997     -0.179618                     0.378748      0.042174 -0.213364
# 249998     -0.574715                    -0.893264     -0.264590 -0.842670
# 249999     -0.196353                     0.756669     -0.176450 -0.987094
#
#         DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %%
# Split the data into ind and dep variable

x = data1_new.drop(['Label',"Weight"], axis=1)
y = data1_new['Label']

# %%
# split the dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 101)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (200000, 17) (50000, 17) (200000,) (50000,)

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# Label
# 0    131501
# 1     68499
# Name: count, dtype: int64
# Label
# 0    32832
# 1    17168
# Name: count, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

from sklearn.linear_model import LogisticRegression

# %%
from sklearn.model_selection import KFold, cross_val_score

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rforest = RandomForestClassifier()
rf = rforest.fit(x_train, y_train)
y_pred_train_rf = rforest.predict(x_train)
y_pred_test_rf = rforest.predict(x_test)
# Confusion Matrix
print(confusion_matrix(y_train, y_pred_train_rf))
print()
print(confusion_matrix(y_test, y_pred_test_rf))
print()
# classification_report
print(classification_report(y_train, y_pred_train_rf))
print()
print(classification_report(y_test, y_pred_test_rf))
print()
# accuracy_score
print("Train Accuracy", accuracy_score(y_train, y_pred_train_rf))
print()
print("Test Accuracy", accuracy_score(y_test, y_pred_test_rf))
# Out:
# [[131501      0]
#  [     4  68495]]
#
# [[29569  3263]
#  [ 5386 11782]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    131501
#            1       1.00      1.00      1.00     68499
#
#     accuracy                           1.00    200000
#    macro avg       1.00      1.00      1.00    200000
# weighted avg       1.00      1.00      1.00    200000
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87     32832
#            1       0.78      0.69      0.73     17168
#
#     accuracy                           0.83     50000
#    macro avg       0.81      0.79      0.80     50000
# weighted avg       0.82      0.83      0.82     50000
#
#
# Train Accuracy 0.99998
#
# Test Accuracy 0.82702

# %% [markdown]
# ### Logistic Regressor

# %%
logit = LogisticRegression()
lr = logit.fit(x_train, y_train)
y_pred_train = logit.predict(x_train)
y_pred_test = logit.predict(x_test)
# Confusion Matrix
print(confusion_matrix(y_train, y_pred_train))
print()
print(confusion_matrix(y_test, y_pred_test))
print()
# classification_report
print(classification_report(y_train, y_pred_train))
print()
print(classification_report(y_test, y_pred_test))
print()
# accuracy_score
print("Train Accuracy", accuracy_score(y_train, y_pred_train))
print()
print("Test Accuracy", accuracy_score(y_test, y_pred_test))
# Out:
# [[113895  17606]
#  [ 30632  37867]]
#
# [[28426  4406]
#  [ 7742  9426]]
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83    131501
#            1       0.68      0.55      0.61     68499
#
#     accuracy                           0.76    200000
#    macro avg       0.74      0.71      0.72    200000
# weighted avg       0.75      0.76      0.75    200000
#
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.82     32832
#            1       0.68      0.55      0.61     17168
#
#     accuracy                           0.76     50000
#    macro avg       0.73      0.71      0.72     50000
# weighted avg       0.75      0.76      0.75     50000
#
#
# Train Accuracy 0.75881
#
# Test Accuracy 0.75704

# %% [markdown]
# ### DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(criterion='entropy')
dt = dtree.fit(x_train, y_train)
y_pred_train_dt = dtree.predict(x_train)
y_pred_test_dt = dtree.predict(x_test)
# Confusion Matrix
print(confusion_matrix(y_train, y_pred_train_dt))
print()
print(confusion_matrix(y_test, y_pred_test_dt))
print()
# classification_report
print(classification_report(y_train, y_pred_train_dt))
print()
print(classification_report(y_test, y_pred_test_dt))
print()
# accuracy_score
print("Train Accuracy", accuracy_score(y_train, y_pred_train_dt))
print()
print("Test Accuracy", accuracy_score(y_test, y_pred_test_dt))
# Out:
# [[131501      0]
#  [     0  68499]]
#
# [[26621  6211]
#  [ 6067 11101]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    131501
#            1       1.00      1.00      1.00     68499
#
#     accuracy                           1.00    200000
#    macro avg       1.00      1.00      1.00    200000
# weighted avg       1.00      1.00      1.00    200000
#
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81     32832
#            1       0.64      0.65      0.64     17168
#
#     accuracy                           0.75     50000
#    macro avg       0.73      0.73      0.73     50000
# weighted avg       0.75      0.75      0.75     50000
#
#
# Train Accuracy 1.0
#
# Test Accuracy 0.75444

# %% [markdown]
# ### XGBoost Classifier

# %%
import xgboost

# %%
from xgboost import XGBClassifier
xgboost = XGBClassifier()
xgb = xgboost.fit(x_train, y_train)
y_pred_train_xgb = xgboost.predict(x_train)
y_pred_test_xgb = xgboost.predict(x_test)
# Confusion Matrix
print(confusion_matrix(y_train, y_pred_train_xgb))
print()
print(confusion_matrix(y_test, y_pred_test_xgb))
print()
# classification_report
print(classification_report(y_train, y_pred_train_xgb))
print()
print(classification_report(y_test, y_pred_test_xgb))
print()
# accuracy_score
print("Train Accuracy", accuracy_score(y_train, y_pred_train_xgb))
print()
print("Test Accuracy", accuracy_score(y_test, y_pred_test_xgb))
# Out:
# [[118987  12514]
#  [ 17447  51052]]
#
# [[29181  3651]
#  [ 4933 12235]]
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89    131501
#            1       0.80      0.75      0.77     68499
#
#     accuracy                           0.85    200000
#    macro avg       0.84      0.83      0.83    200000
# weighted avg       0.85      0.85      0.85    200000
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87     32832
#            1       0.77      0.71      0.74     17168
#
#     accuracy                           0.83     50000
#    macro avg       0.81      0.80      0.81     50000
# weighted avg       0.83      0.83      0.83     50000
#
#
# Train Accuracy 0.850195
#
# Test Accuracy 0.82832

# %% [markdown]
# ### Naive Bayes Theorem

# %%
from sklearn.naive_bayes import BernoulliNB
bernb = BernoulliNB()
bnb = bernb.fit(x_train, y_train)
y_pred_train_bnb = bernb.predict(x_train)
y_pred_test_bnb = bernb.predict(x_test)
# Confusion Matrix
print(confusion_matrix(y_train, y_pred_train_bnb))
print()
print(confusion_matrix(y_test, y_pred_test_bnb))
print()
# classification_report
print(classification_report(y_train, y_pred_train_bnb))
print()
print(classification_report(y_test, y_pred_test_bnb))
print()
# accuracy_score
print("Train Accuracy", accuracy_score(y_train, y_pred_train_bnb))
print()
print("Test Accuracy", accuracy_score(y_test, y_pred_test_bnb))
# Out:
# [[104333  27168]
#  [ 25326  43173]]
#
# [[26057  6775]
#  [ 6407 10761]]
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80    131501
#            1       0.61      0.63      0.62     68499
#
#     accuracy                           0.74    200000
#    macro avg       0.71      0.71      0.71    200000
# weighted avg       0.74      0.74      0.74    200000
#
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80     32832
#            1       0.61      0.63      0.62     17168
#
#     accuracy                           0.74     50000
#    macro avg       0.71      0.71      0.71     50000
# weighted avg       0.74      0.74      0.74     50000
#
#
# Train Accuracy 0.73753
#
# Test Accuracy 0.73636

# %% [markdown]
# ## Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting = VotingClassifier(estimators=[('logit', lr ),('dtree', dt),('rforest', rf),('xgboost', xgb),("bnb",bnb)])
voting_evc = voting.fit(x_train, y_train)
y_pred_train_voting = voting.predict(x_train)
y_pred_test_voting = voting.predict(x_test)
# Confusion Matrix
print(confusion_matrix(y_train, y_pred_train_voting))
print()
print(confusion_matrix(y_test, y_pred_test_voting))
print()
# classification_report
print(classification_report(y_train, y_pred_train_voting))
print()
print(classification_report(y_test, y_pred_test_voting))
print()
# accuracy_score
print("Train Accuracy", accuracy_score(y_train, y_pred_train_voting))
print()
print("Test Accuracy", accuracy_score(y_test, y_pred_test_voting))
# Out:
# [[125681   5820]
#  [ 13634  54865]]
#
# [[29576  3256]
#  [ 5722 11446]]
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93    131501
#            1       0.90      0.80      0.85     68499
#
#     accuracy                           0.90    200000
#    macro avg       0.90      0.88      0.89    200000
# weighted avg       0.90      0.90      0.90    200000
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87     32832
#            1       0.78      0.67      0.72     17168
#
#     accuracy                           0.82     50000
#    macro avg       0.81      0.78      0.79     50000
# weighted avg       0.82      0.82      0.82     50000
#
#
# Train Accuracy 0.90273
#
# Test Accuracy 0.82044

# %%
accuracy_logit = accuracy_score(y_test, y_pred_test)
accuracy_dtree = accuracy_score(y_test, y_pred_test_dt)
accuracy_rf = accuracy_score(y_test, y_pred_test_rf)
accuracy_xgb = accuracy_score(y_test, y_pred_test_xgb)
accuracy_bnb = accuracy_score(y_test, y_pred_test_bnb)
accuracy_voting = accuracy_score(y_test, y_pred_test_voting)

# %%
point1 = ["Logistic", 'Dtree','RForest','XGBoost','BNB','Voting']
point2 = [accuracy_logit,accuracy_dtree,accuracy_rf,accuracy_xgb,accuracy_bnb,accuracy_voting]

final_output = pd.DataFrame({"Method Used": point1, "Accuracy":point2})
print(final_output)

# visualization

chart = sns.barplot(x="Method Used", y="Accuracy", data=final_output)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
print(chart)
# Out:
#   Method Used  Accuracy
# 0    Logistic   0.75704
# 1       Dtree   0.75444
# 2     RForest   0.82702
# 3     XGBoost   0.82832
# 4         BNB   0.73636
# 5      Voting   0.82044
# Axes(0.125,0.11;0.775x0.77)
